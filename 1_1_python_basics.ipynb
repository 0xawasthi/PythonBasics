# %% [markdown]
# <a href="https://colab.research.google.com/github/0xawasthi/PythonBasics/blob/main/1_1_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basics

# %%
import sys
print (sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
age = 22
if age>= 18:
  print("you are eligible to vote")
else:
  print("you are not eligible to vote")
# Out:
# you are eligible to vote

# %% [markdown]
# ## Python Practice

# %%
# Minutes to Seconds

# get an input integer
time_minutes = int(input("Enter time in minutes:"))

# convert time_minutes into second
time_seconds = time_minutes *60

# print the result
print(time_seconds)
# Out:
# Enter time in minutes:2
# 120

# %%
# Area of a triangle

# take input for base and height
base= float(input("Enter base:"))
height=float(input("Enter height:"))

# calculate the area
area = base*height*0.5

# print area
print(area)
# Out:
# Enter base:5
# Enter height:1
# 2.5

# %%
# Swap values

# get the integer inputs for n1 and n2
n1 = int(input("Enter a number:"))
n2 = int(input("Enter a number:"))

# create a temporary variable and swap the values
temp = n1
n1 = n2
n2 = temp

# print the values of n1 and n2
print(n1)
print(n2)
# Out:
# Enter a number:2
# Enter a number:9
# 9
# 2
